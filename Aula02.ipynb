# %% [markdown]
# <a href="https://colab.research.google.com/github/kxznn/chatbot/blob/main/Aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %%
# !pip install llama_index.llms.groq # Install llama

# %%
from google.colab import userdata
chat_api = userdata.get('api_chat26')

# %%
# Chat_api

# %%
from llama_index.llms.groq import Groq # Importando o metodo Groq a partir do framework llama

# %%
llm = Groq(model='llama-3.3-70b-versatile', api_key=chat_api)
response = llm.complete('Qual foi o ultimo titulo do Santos FC ?')

# %%
response
# Out:
# CompletionResponse(text='O último título do Santos FC foi o Campeonato Paulista de 2016. No entanto, é importante notar que o clube tem uma rica história e conquistou muitos títulos ao longo dos anos, incluindo a Copa Libertadores da América em 1962 e 1963, e o Campeonato Brasileiro em 2002, 2004 e 2010.\n\nAqui estão alguns dos principais títulos do Santos FC:\n\n* Campeonato Brasileiro: 2002, 2004, 2010\n* Copa Libertadores da América: 1962, 1963\n* Campeonato Paulista: 1935, 1955, 1956, 1958, 1960, 1961, 1962, 1964, 1965, 1967, 1968, 1969, 1973, 1978, 1984, 2006, 2007, 2010, 2011, 2012, 2015, 2016\n* Copa do Brasil: 2010\n\nÉ importante lembrar que os títulos podem variar ao longo do tempo, e é sempre uma boa ideia verificar as informações mais atualizadas para ter uma visão mais precisa da história do clube.', additional_kwargs={'prompt_tokens': 44, 'completion_tokens': 288, 'total_tokens': 332}, raw=ChatCompletion(id='chatcmpl-89c7f20f-ea26-41b0-8ce8-a457bd8b56e7', choices=[Choi
# ...

# %%
paragrafos = response.text.split('\n\n')
for paragrafos in paragrafos:
  print (paragrafos)
print()
# Out:
# O último título do Santos FC foi o Campeonato Paulista de 2016. No entanto, é importante notar que o clube tem uma rica história e conquistou muitos títulos ao longo dos anos, incluindo a Copa Libertadores da América em 1962 e 1963, e o Campeonato Brasileiro em 2002, 2004 e 2010.
# Aqui estão alguns dos principais títulos do Santos FC:
# * Campeonato Brasileiro: 2002, 2004, 2010
# * Copa Libertadores da América: 1962, 1963
# * Campeonato Paulista: 1935, 1955, 1956, 1958, 1960, 1961, 1962, 1964, 1965, 1967, 1968, 1969, 1973, 1978, 1984, 2006, 2007, 2010, 2011, 2012, 2015, 2016
# * Copa do Brasil: 2010
# É importante lembrar que os títulos podem variar ao longo do tempo, e é sempre uma boa ideia verificar as informações mais atualizadas para ter uma visão mais precisa da história do clube.
